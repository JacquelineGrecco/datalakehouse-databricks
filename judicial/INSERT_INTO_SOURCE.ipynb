# %%
# %sql

-- CREATE TABLE dev_bronze.sql_server.customers (
--         customer_id INT PRIMARY KEY,
--         customer_name VARCHAR(10) NOT NULL,
--         email VARCHAR(10),
--         created_at TIMESTAMP);  


-- -- Insert sample data
-- TRUNCATE TABLE dev_bronze.sql_server.customers;

INSERT INTO dev_bronze.sql_server.customers (customer_id, customer_name, email, created_at) VALUES
(1, 'Superior', 'contact', '2023-01-15'),
(2, 'Federal', 'info', '2023-02-20'),
(3, 'State', 'contato', '2023-03-10'),
-- (4, 'Labor', 'atendimento', '2023-04-05'),
-- (5, 'Electoral Court', 'relacionamento@tse', '2023-05-12'),
-- (6, 'Military Court', 'contact@stm', '2023-06-18'),
-- (7, 'Federal Supreme Court', 'contato@stf', '2023-07-22'),
-- (8, 'Court of Accounts', 'atendimento', '2023-08-30'),
-- (9, 'State Court of Rio', 'info@tjrj', '2023-09-14'),
(10, 'Regional', 'contato', '2023-10-25');

SELECT * FROM dev_bronze.sql_server.customers;
